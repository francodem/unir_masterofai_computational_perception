# %% [markdown]
# <a href="https://colab.research.google.com/github/francodem/unir_masterofai_computational_perception/blob/main/unir_masterofai_computational_perception_extra_opencv_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
# get the image from a path
# CHANGE the PATH by your own image path to read
PATH = "/content/images/DALL·E 2023-11-06 16.44.48 - Create a hyper-realistic image of a diverse team of AI engineers collaborating in a high-tech office environment. The team includes a Middle-Eastern d.png"
img = cv.imread(PATH)

# resize the image
dimensions = (420, 420)
img = cv.resize(img, dimensions)

# %%
# validating the current image on the PATH
if img is None:
  print("Could not read the image.")

# %%
# showing the image
cv2_imshow(img)
k = cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=420x420>

# %%
# changing the color to B/W
gray_image = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# showing the image again
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=420x420>
